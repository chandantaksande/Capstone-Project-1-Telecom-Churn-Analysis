# %% [markdown]
# # **1. Project Name**    - TELECOM CHURN ANALYSIS

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Team
# ##### **Team Member 1 -**  Chandan Sudhir Taksande
# ##### **Team Member 2 -**  Nikhil Arvind Arjune

# %% [markdown]
# # **2. Project Summary -**
#
# When we had our first AMA session, next day we became a team of two people. And we visited various site, where we explored few case studies, we found that it was relatively easy for us to create interactive charts with only small amounts of data. Our first step was to study all the projects topics given on Alma Better Dashboard. We spent three days only to select for project topic. During these three days, each of us carefully observe given dataset for each project and had group discussion twice a day. In that group discussion we talk about various possibilities and we can obtain from given dataset. We also discuss how can we approach this topic in depth and how should we start working on it. We had lot of debates on which topic we should proceed. The most interesting discussion we had on was world bank education analysis. As the data had lot of irregularities and complex term we never heard about. We thought we could learn lot of things from doing this project. As we proceed with this topic, we had lot of difficulty on coming to conclusion. At the end we drop this topic as we were having lot of difficulty.
#   We came from non-IT background and we selected telecom churn capstone project cause there were a lot of things we could learn while working on it and do lot of exploring too, without any hardcore difficulty. The telecom churn was one of the most important topics we could choose for our capstone project. There were a lot of things to learn from this topic, such as chart plotting, data wrangling, and creating a useful visualization.
# Each of us created a personal rough collab and tried looking for relation between each data mention in csv file. In the rough collab we had our personal data visualization and wrangling data.
# Then we came on alma better table and had a group activity again. We shared our personal data visualization, wrangling of data and discussed in the group with each other. After the discussion and comparing our collab, we studied each others personal colab to find out what are each others mistakes and important points ,which is most logical to be noted. Finally we created a list of our own mistake and important point so that when we start working individually on actual project, so we won't repeat any mistake or trend already done by other team members.
# We again had a group discussion session next day on alma better table. We again studies each others visualization and  data wrangling. And finally created a combine rough colab from the two colab that were created by each of us separately. In that collab we combined data visualization and wrangling data from each of us. Then we filtered out unnecessary or repeated observation. And tried looking for each and every possible scenario we could come up with. During this one week period we learn and explore a lot of things that we couldn’t even do it last month sessions. Truly a marvelous experience. Thank you!

# %% [markdown]
# # **3. GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **4. Problem Statement**

# %% [markdown]
# Orange S.A., formerly France Telecom S.A., is a French multinational telecommunications corporation. The Orange Telecom's Churn Dataset, consists of cleaned customer activity data (features), along with a churn label specifying whether a customer cancelled the subscription. Explore and analyze the data to discover key factors responsible for customer churn and come up with ways/recommendations to ensure customer retention.

# %% [markdown]
# # **5. Business Objective**

# %% [markdown]
# 1. To identify churn customers, so company can find a way to increase customer retaintion rate.
# 2. To find relation between given data, se we can identify churn customer as early as possible
# 3. To find churn  causing factors.

# %% [markdown]
# # **6. Data Introduction**

# %% [markdown]
# # 6.1 Importing Library & Mounting Data

# %%
# Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Mounting drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
#import file
telecom_churn_df=pd.read_csv('/content/drive/MyDrive/Alma Better/Capstone Project/Capstone Project 1- Telecom Churn Analysis/Telecom Churn.csv')

# %% [markdown]
# # 6.2 Data Overview

# %%
# Top rows from telecom_churn_df
telecom_churn_df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
# Last rows from telecom_churn_df
telecom_churn_df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
# Dataset Rows & Columns count
telecom_churn_df.shape
# Out:
# (3333, 20)

# %%
# Dataset Information
telecom_churn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %% [markdown]
# # 6.3 Dataset Features

# %% [markdown]
# 1. State: It contains name of states (Total 51 states)
#
# 2. Account Length: It displays the number of months the account has been active.
#
# 3. Area Code: These are the codes for the specific areas that are used to identify them.
#
# 4. International Plan: Yes-indicates that the customer had International Plan, while No-indicates that the customer had not subscribed to International Plan.
#
# 5. Voice Mail Plan: Yes indicates that the customer had Voice Mail Plan, while No indicates that the customer had not subscribed to Voice Mail Plan.
#
# 6. Number vmail messages: Number of voice messages done by customers.
#
# 7. Total day minutes: Total amount of time spent in the morning.
#
# 8. Total day calls: Total number of calls made by the customer in the morning.
#
# 9. Total day charge: It is the total cost of services used by customers in the morning.
#
# 10. Total eve minutes: Total amount of time spent in the Evening.
#
# 11. Total eve calls: Total number of calls made by the customer in the Evening.
#
# 12. Total eve charge: It is the total cost of services used by customers in the evening.
#
# 13. Total night minutes: Total amount of time spent in the Night.
#
# 14. Total night calls: Total number of calls made by the customer in the Night.
#
# 15. Total night charge: It is the total cost of services used by customers in the Night.
#
# 16. Total intl minutes: Total amount of time spent by customer over international calls.
#
# 17. Total intl calls: Total of the number of international calls made by the customer
#
# 18. Total intl charge: It is the total cost of international services used by customers
#
# 19. Customer service calls: Number of calls made by customer to the customer service
#
# 20. Churn: This is our dependent variable that describes whether or not customers is churned.

# %% [markdown]
# # 6.4 Data Cleaning

# %%
# Checking Duplicate value in dataset
telecom_churn_df.duplicated().value_counts()
# Out:
# False    3333
# dtype: int64

# %% [markdown]
# From above result, We can see that there are no duplicates in given data set

# %%
# Checking blank cells or blank data
print(telecom_churn_df.isnull().sum())
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %% [markdown]
# From above result we can see that there are no null values in given dataset as well. Now we have done data cleaning. Let's move towards next part.

# %%
# Dataset Columns
telecom_churn_df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
# Dataset Describe
telecom_churn_df.describe().T
# Out:
#                          count        mean        std     min     25%     50%  \
# Account length          3333.0  101.064806  39.822106    1.00   74.00  101.00
# Area code               3333.0  437.182418  42.371290  408.00  408.00  415.00
# Number vmail messages   3333.0    8.099010  13.688365    0.00    0.00    0.00
# Total day minutes       3333.0  179.775098  54.467389    0.00  143.70  179.40
# Total day calls         3333.0  100.435644  20.069084    0.00   87.00  101.00
# Total day charge        3333.0   30.562307   9.259435    0.00   24.43   30.50
# Total eve minutes       3333.0  200.980348  50.713844    0.00  166.60  201.40
# Total eve calls         3333.0  100.114311  19.922625    0.00   87.00  100.00
# Total eve charge        3333.0   17.083540   4.310668    0.00   14.16   17.12
# Total night minutes     3333.0  200.872037  50.573847   23.20  167.00  201.20
# Total night calls       3333.0  100.107711  19.568609   33.00   87.00  100.00
# ...

# %%
# Finding Unique Values for each variable in column.
telecom_churn_df.nunique()
# Out:
# State                       51
# Account length             212
# Area code                    3
# International plan           2
# Voice mail plan              2
# Number vmail messages       46
# Total day minutes         1667
# Total day calls            119
# Total day charge          1667
# Total eve minutes         1611
# Total eve calls            123
# Total eve charge          1440
# Total night minutes       1591
# Total night calls          120
# Total night charge         933
# Total intl minutes         162
# Total intl calls            21
# Total intl charge          162
# Customer service calls      10
# Churn                        2
# dtype: int64

# %% [markdown]
# ## 7. Data Wrangling & Visualization

# %% [markdown]
# #7.1  Overall Scenario

# %%
#calculating total chrun values
telecom_churn_df["Churn"].value_counts()
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
# visualization of above data 
plt.rcParams['figure.figsize'] = (10, 8)
sns.countplot(x=telecom_churn_df.Churn)

# %%
#visualization of above data in percentage
plt.figure(figsize=(10,6))
plt.pie(telecom_churn_df['Churn'].value_counts(), explode = (0,0.3),autopct='%1.1f%%',shadow=True,radius = 2.0, labels = ['Not churned customer','Churned customer'],colors=['#003f5c' ,'#bc5090'])
#circle = plt.Circle( (0,0), 1, color='white')
p=plt.gcf()
#p.gca().add_artist(circle)
plt.show()

# %% [markdown]
# By analysing overall data, it is found that total 14.5% users are leaving.

# %% [markdown]
# # 7.2 STATE VS CHURN

# %%
#First ploting given data of "State" against "Churn" for better understanding
plt.figure(figsize=(20,10))
sns.countplot(x="State",data=telecom_churn_df,hue="Churn")
plt.title("State vs Chrun")
plt.xlabel("State")
plt.ylabel("Users")
# Out:
# Text(0, 0.5, 'Users')

# %%
#store top 18 states with highest churn rate
states_with_highest_churn_rates=((telecom_churn_df.groupby(['State'])['Churn'].mean())*100).sort_values(ascending = False).head(18)
print(states_with_highest_churn_rates)
# Out:
# State
# NJ    26.470588
# CA    26.470588
# TX    25.000000
# MD    24.285714
# SC    23.333333
# MI    21.917808
# MS    21.538462
# NV    21.212121
# WA    21.212121
# ME    20.967742
# MT    20.588235
# AR    20.000000
# KS    18.571429
# NY    18.072289
# MN    17.857143
# PA    17.777778
# MA    16.923077
# CT    16.216216
# Name: Churn, dtype: float64

# %%
#creating a variable which will give top 10 states with highest churn rate
states_with_highest_churn_rates=((telecom_churn_df.groupby(['State'])['Churn'].mean())*100).sort_values(ascending = False).head(18)

#Ploting bar chart of top 10 states with highest churn rate 
plt.rcParams['figure.figsize'] = (15, 8)
color = plt.cm.copper(np.linspace(0, 0.5, 20))
states_with_highest_churn_rates.plot.bar()
plt.title(" State with Most Churn Percentage")
plt.xlabel('state')
plt.ylabel('percentage')
plt.show()

# %% [markdown]
# Out of 51 states, following are the list of 18 states which has highest churned rate. For other state, Churn rate was dropped drastically.
# States_list:-NJ
# CA
# TX
# MD
# SC
# MI
# MS
# NV
# WA
# ME
# MT
# AR
# KS
# NY
# MN
# PA
# MA
# CT

# %% [markdown]
# # 7.3 Account Length Vs Churn

# %% [markdown]
# Account Length refers to from how long user has been taking services of our company. So lets see if users duration with our services has any impact on churn rate.We divided account length into three categories.
# 1. From 0 to 12 (Short Term Users)
# 2. From 13 to 100 (Middle Term Users)
# 3. From 100 onwards (Long Term Users)

# %%
# Finding short term user which are using using service from not long i.e. from 0 to 12
short_term_user=telecom_churn_df[(telecom_churn_df['Account length']>0) & (telecom_churn_df['Account length']<=12)].loc[:,['Churn']].value_counts()
short_term_user
# Out:
# Churn
# False    31
# True      3
# dtype: int64

# %%
# Ploting pie chart for short_term_user
plt.figure(figsize=(10,6))
plt.pie(short_term_user, explode = (0,0.3),autopct='%1.1f%%',shadow=True,radius = 2.0, labels = ['Not churned customer','Churned customer'])
circle = plt.Circle( (0,0), 1, color='white')
p=plt.gcf()
plt.title("Short Term User vs Churn")
p.gca().add_artist(circle)
plt.show()

# %%
# Finding middle term user which are using using service from 13 to 100
middle_term_user=telecom_churn_df[(telecom_churn_df['Account length']>=13) & (telecom_churn_df['Account length']<=100)].loc[:,['Churn']].value_counts()
middle_term_user
# Out:
# Churn
# False    1399
# True      231
# dtype: int64

# %%
# ploting donought chart for middle_term_user
plt.figure(figsize=(10,6))
plt.pie(middle_term_user, explode = (0,0.3),autopct='%1.1f%%',shadow=True,radius = 2.0, labels = ['Not churned customer','Churned customer'])
circle = plt.Circle( (0,0), 1, color='white')
p=plt.gcf()
plt.title("Middle Term User vs Churn")
p.gca().add_artist(circle)
plt.show()

# %%
# Finding long term user which are using using service from long period i.e. from 101 to 243
long_term_users=telecom_churn_df[(telecom_churn_df['Account length']>100) & (telecom_churn_df['Account length']<=telecom_churn_df['Account length'].max())].loc[:,['Churn']].value_counts()
long_term_users
# Out:
# Churn
# False    1420
# True      249
# dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.pie(long_term_users, explode = (0,0.3),autopct='%1.1f%%',shadow=True,radius = 2.0, labels = ['Not churned customer','Churned customer'])
circle = plt.Circle( (0,0), 1, color='white')
p=plt.gcf()
plt.title("Long Term User vs Churn")
p.gca().add_artist(circle)
plt.show()

# %% [markdown]
# Account length i.e. time period from which user is using services, has no effect on churn rate whatsoever

# %% [markdown]
# # 7.4 Area Code Vs Churn

# %%
# First we will check wheather the "area code" i.e. area wise user distribution have some effect on churn rate.
telecom_churn_df.groupby(['Area code'])['Churn'].value_counts().unstack()
# Out:
# Churn      False  True
# Area code
# 408          716   122
# 415         1419   236
# 510          715   125

# %%
# Ploting count plot for Area Code vs Churn
plt.figure(figsize=(15,7.5))
sns.countplot(x="Area code",data=telecom_churn_df,hue="Churn",palette = "Set2")
plt.title("Area code vs Chrun")
plt.xlabel("Area Code")
plt.ylabel("Users")
# Out:
# Text(0, 0.5, 'Users')

# %%
# Extracting chrun data for for "Area code-408" only. 
area_code_1_df=telecom_churn_df[telecom_churn_df["Area code"]==408]["Churn"].value_counts()
area_code_1_df
# Out:
# False    716
# True     122
# Name: Churn, dtype: int64

# %%
# Ploting donought chart for "Area Code-408 vs Churn"
plt.figure(figsize=(10,6))
plt.pie(area_code_1_df, explode = (0,0.3),autopct='%1.1f%%',shadow=True,radius = 2.0, labels = ['Not churned customer','Churned customer'])
circle = plt.Circle( (0,0), 1, color='white')
p=plt.gcf()
plt.title("Area code-408 Vs Churn")
p.gca().add_artist(circle)
plt.show()

# %%
# Extracting chrun data for for "Area code-415" only. 
area_code_2_df=telecom_churn_df[telecom_churn_df["Area code"]==415]["Churn"].value_counts()
area_code_2_df
# Out:
# False    1419
# True      236
# Name: Churn, dtype: int64

# %%
# Ploting donought chart for "Area Code-415 vs Churn"
plt.figure(figsize=(10,6))
plt.pie(area_code_2_df, explode = (0,0.3),autopct='%1.1f%%',shadow=True,radius = 2.0, labels = ['Not churned customer','Churned customer'])
circle = plt.Circle( (0,0), 1, color='white')
p=plt.gcf()
plt.title("Area code-415 Vs Churn")
p.gca().add_artist(circle)
plt.show()

# %%
# Extracting chrun data for for "Area code-510" only. 
plt.figure(figsize=(10,6))
area_code_3_df=telecom_churn_df[telecom_churn_df["Area code"]==510]["Churn"].value_counts()
area_code_3_df
# Out:
# False    715
# True     125
# Name: Churn, dtype: int64

# %%
# Ploting donought chart for "Area Code-510 vs Churn"
plt.figure(figsize=(10,6))
plt.pie(area_code_3_df, explode = (0,0.3),autopct='%1.1f%%',shadow=True,radius = 2.0, labels = ['Not churned customer','Churned customer'])
circle = plt.Circle( (0,0), 1, color='white')
p=plt.gcf()
plt.title("Area code-510 Vs Churn")
p.gca().add_artist(circle)
plt.show()

# %% [markdown]
# Area code also has no effect on churned rate, as for each area code the churn rate for each region was around 14.5%.

# %% [markdown]
# # 7.5 International Plan VS Churn

# %%
# Checking International plan and Churn data in tabular form
pd.crosstab(telecom_churn_df["Churn"],telecom_churn_df["International plan"])
# Out:
# International plan    No  Yes
# Churn
# False               2664  186
# True                 346  137

# %%
#printing observation from above data
print(f"Total Non-International Plan Users are {2664+346}")
print(f"Out of Total Non-International Plan Users {346} users are churn")
print(f"Total International Plan users are {186+137}")
print(f"Out of Total International Plan Users {186} users are churn")
# Out:
# Total Non-International Plan Users are 3010
# Out of Total Non-International Plan Users 346 users are churn
# Total International Plan users are 323
# Out of Total International Plan Users 186 users are churn

# %%
# Ploting countplot for International plan vs churn
plt.figure(figsize=(15,7.5))
sns.countplot(x="International plan",data=telecom_churn_df,hue="Churn",palette = "Set2")
plt.title("International plan vs Chrun")
plt.xlabel("International plan")
plt.ylabel("Users")
# Out:
# Text(0, 0.5, 'Users')

# %%
# Finding values for only international plan against churn
international_plan_churn_data=telecom_churn_df[telecom_churn_df["International plan"]=="Yes"]["Churn"].value_counts()
international_plan_churn_data
# Out:
# False    186
# True     137
# Name: Churn, dtype: int64

# %%
# Ploting donought chart for International plan users vs Churn
plt.figure(figsize=(10,6))
plt.pie(international_plan_churn_data, explode = (0,0.3),autopct='%1.1f%%',shadow=True,radius = 2.0, labels = ['Not churned customer','Churned customer'])
circle = plt.Circle( (0,0), 1, color='white')
p=plt.gcf()
p.gca().add_artist(circle)
plt.show()

# %% [markdown]
# There are total 323 International Plan users and out of them 186 users are churn. So, overall churn rate for international plan user becomes 42.4%. By observations, there are 3 possible reason for this.
# a) Either the international plan has high charges.
# b) There are network related issues.
# c) Maybe there is another service provider which offers cheap plans.

# %% [markdown]
# ## 7.6 VOICE MAIL PLAN VS CHURN

# %%
# Finding relation Voice plan users and non-user vs Churn in tabular form
pd.crosstab(telecom_churn_df["Churn"],telecom_churn_df["Voice mail plan"])
# Out:
# Voice mail plan    No  Yes
# Churn
# False            2008  842
# True              403   80

# %%
#printing observation from above data
print(f"Total Non-Voice Plan Users are {2008+842}")
print(f"Out of Total Non-Voice Plan Users {403} users are churn")
print(f"Total Voice Plan users are {842+80}")
print(f"Out of Total Voice Plan Users {80} users are churn")
# Out:
# Total Non-Voice Plan Users are 2850
# Out of Total Non-Voice Plan Users 403 users are churn
# Total Voice Plan users are 922
# Out of Total Voice Plan Users 80 users are churn

# %%
#Ploting countplot chart for Voice plan users and non-user vs Churn
plt.figure(figsize=(15,7.5))
sns.countplot(x="Voice mail plan",data=telecom_churn_df,hue="Churn",palette = "Set2")
plt.title("Voice mail plan")
plt.xlabel("Voice mail plan")
plt.ylabel("Users")
# Out:
# Text(0, 0.5, 'Users')

# %%
# Finding data for voice plan users and churn users in tabular form
Voice_mail_plan_churn_data=telecom_churn_df[telecom_churn_df["Voice mail plan"]=="Yes"]["Churn"].value_counts()
Voice_mail_plan_churn_data
# Out:
# False    842
# True      80
# Name: Churn, dtype: int64

# %%
#Ploting donought chart for "Voice plan users Vs Unchurn users"
plt.figure(figsize=(10,6))
plt.pie(Voice_mail_plan_churn_data, explode = (0,0.3),autopct='%1.2f%%',shadow=True,radius = 2.0, labels = ['Not churned customer','Churned customer'])
circle = plt.Circle( (0,0), 1, color='white')
plt.title("Voice plan users Vs churn users")
p=plt.gcf()
p.gca().add_artist(circle)
plt.show()

# %%
# Finding data for voice plan users and churn users in tabular form
Voice_mail_plan_churn_data_1=telecom_churn_df[telecom_churn_df["Voice mail plan"]=="No"]["Churn"].value_counts()
Voice_mail_plan_churn_data_1
# Out:
# False    2008
# True      403
# Name: Churn, dtype: int64

# %%
#Ploting donought chart for "Non-Voice plan users Vs Churn users"
plt.figure(figsize=(10,6))
plt.pie(Voice_mail_plan_churn_data_1, explode = (0,0.3),autopct='%1.2f%%',shadow=True,radius = 2.0, labels = ['Not churned customer','Churned customer'])
circle = plt.Circle( (0,0), 1, color='white')
plt.title("Non-Voice plan users Vs churn users")
p=plt.gcf()
p.gca().add_artist(circle)
plt.show()

# %% [markdown]
# Total Voice Plan users are 922 and out of total Voice Plan Users 80 users are churn. So the churn rate for voice plan users becomes 8.68%. From oberservation, we can say that voice plan users have no effect on churned rate.So voice plan user are satisfied with company services.

# %% [markdown]
# #7.7 Calling Time VS Churn

# %% [markdown]
# Here we wanted to see if total calling time has some kind of effect on churn rate.
# so we added new column called "Total Talk time" and plot it against churn.
#
# Note:- In "Total Talk Time" column value, we didn't add 'Total intl minutes' in 'Total Talk Time' cause we already did analysis for international users above. And it already has big impact on churn users.If added it would have affected the result and We also wanted to find out other factors which are affecting churn rate

# %%
# Creating new column called "Total Talk Time" by adding "Total Day Minutes","Total eve Minutes", "Total night minutes" together
telecom_churn_df["Total Talk Time"]=telecom_churn_df["Total day minutes"]+telecom_churn_df["Total eve minutes"]+telecom_churn_df["Total night minutes"]
telecom_churn_df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# Checking relation between "Total Talk Time" vs "Churn" in Tabular form
pd.crosstab(telecom_churn_df["Churn"],telecom_churn_df["Total Talk Time"])
# Out:
# Total Talk Time  275.2  292.6  300.9  305.6  311.4  311.7  326.0  326.7  \
# Churn
# False                1      1      1      1      1      0      1      0
# True                 0      0      0      0      0      1      0      1
#
# Total Talk Time  333.7  337.5  ...  817.9  820.2  821.2  821.2  831.0  832.6  \
# Churn                          ...
# False                0      1  ...      0      1      0      0      1      0
# True                 1      0  ...      1      0      1      1      0      1
#
# Total Talk Time  841.3  849.4  871.7  876.9
# Churn
# False                0      0      0      0
# True                 1      1      1      1
#
# [2 rows x 2395 columns]

# %%
# Ploting above obtained value as it in countplot
plt.figure(figsize=(15,7.5))
sns.countplot(x="Total Talk Time",data=telecom_churn_df,hue="Churn",palette = "Set2")
plt.title("Total Talk Time")
plt.xlabel("Total Talk Time")
plt.ylabel("Avg. User")
# Out:
# Text(0, 0.5, 'Avg. User')

# %% [markdown]
# As the talktime along the x-axis increases, churn users(Red Lines) also increases. And at the end of x axis we can see that red lines i.e. churned users are more.

# %%
# Ploting boxplot for better understanding and visualization of data
sns.boxplot(x='Churn', y='Total Talk Time', data = telecom_churn_df)
plt.show()

# %% [markdown]
# It is observe that as total talk time increases, so does the churn rate.

# %% [markdown]
# # 7.8 Service Charges VS Churn

# %% [markdown]
# Here we wanted to see if total service charges has some kind of effect on churn rate.
# so we added new column called "Total Charges" and plot him against churn.
#
# Note:- In 'Total Charges' we didn't add 'Total intl cahrges' in 'Total Charges' cause we already did analysis for international users above. And it already has big impact on churn users.If added it would have affected the result and We also wanted to find out other factors which are affecting churn rate

# %%
# Creating new column called "Total Charges" by adding "Total Day charges","Total eve Charges", "Total night Charges" together
telecom_churn_df["Total Charges"]=telecom_churn_df["Total day charge"]+telecom_churn_df["Total eve charge"]+telecom_churn_df["Total night charge"]
telecom_churn_df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
telecom_churn_df.groupby(["Total Charges"])["Churn"].value_counts()
# Out:
# Total Charges  Churn
# 19.98          False    1
# 21.09          True     1
# 23.39          False    1
# 23.93          False    1
# 23.97          False    1
#                        ..
# 87.88          True     1
# 88.31          True     1
# 89.47          True     1
# 90.83          True     1
# 92.56          True     1
# Name: Churn, Length: 2722, dtype: int64

# %%
plt.figure(figsize=(15,7.5))
sns.countplot(x="Total Charges",data=telecom_churn_df,hue="Churn",palette = "Set2")
plt.title("Total Charges")
plt.xlabel("Total Charges")
plt.ylabel("Avg. User")
# Out:
# Text(0, 0.5, 'Avg. User')

# %% [markdown]
# As the Total Charges along the x-axis increases, churn users(Orange Lines) also increases. And at the end of x axis we can see that orange lines i.e. churned users are more.

# %%
sns.boxplot(x='Churn', y='Total Talk Time', data = telecom_churn_df)
plt.show()

# %% [markdown]
# It is observe that as total service charges increases, so does the churn rate.

# %% [markdown]
# # 7.9 Total Talk Time vs Total Service Charges

# %% [markdown]
# In 7.7(Total Talk Time) and 7.8(Total Charges) we found out that, churn rate is increases as the talk time and service charges were increasing. And we know that talk time and charges are related. So for better understanding and relation between data, we plot scatterplot.

# %%
sns.scatterplot(x='Total Talk Time', y='Total Charges', data= telecom_churn_df, marker = '+')

# %% [markdown]
# It is observed that as the total talk time increases, the total charges also increases. And it is directly affecting the churn rate as we seen in 7.7 and 7.8. So we can say that because of high charges on talk time people are leaving.

# %% [markdown]
# As per data of total talk time and Total charges(refer 7.7 and 7.8 ) is increasing, so does the churn rate. And in total talk time vs Total charges plot, it is found that for high talk time, high charges were charged. And we think because of high talk time service charges users are leaving our services.

# %% [markdown]
# #7.10 Customer service calls vs Churn

# %%
# Finding relational data between "Customer service calls" and "Churn" data for better understanding
telecom_churn_df.groupby(["Customer service calls"])["Churn"].value_counts().unstack()
# Out:
# Churn                    False   True
# Customer service calls
# 0                        605.0   92.0
# 1                       1059.0  122.0
# 2                        672.0   87.0
# 3                        385.0   44.0
# 4                         90.0   76.0
# 5                         26.0   40.0
# 6                          8.0   14.0
# 7                          4.0    5.0
# 8                          1.0    1.0
# 9                          NaN    2.0

# %%
#Ploting countplot for above obtain data for better visualization 
plt.figure(figsize=(15,7.5))
sns.countplot(x="Customer service calls",data=telecom_churn_df,hue="Churn",palette = "Set2")
plt.title("Customer service calls")
plt.xlabel("Customer service calls")
plt.ylabel("Avg. User")
# Out:
# Text(0, 0.5, 'Avg. User')

# %% [markdown]
# If we look at above table and and graph, it is obeserved that above 4 customer service calls, percentage of churn users are increase drastically.

# %%
# Creating a column which has record of more than 3 service calls only
telecom_churn_df['High Service call'] = telecom_churn_df['Customer service calls'] > 3

# Finding relational data between "High service calls" and "Churn" data and storing it in new variable
cross_table_high_service_calls_vs_churn=pd.crosstab(telecom_churn_df['High Service call'], telecom_churn_df['Churn'])

#printing whole cross table present in "cross_table_high_service_calls_vs_churn"
print("High Service calls vs churn users and non-churn users")
print(cross_table_high_service_calls_vs_churn)

#printing only high service call users data from "cross_table_high_service_calls_vs_churn" 
print("\n\nHigh Service calls vs only churn users")
print(cross_table_high_service_calls_vs_churn.iloc[:,1:])
# Out:
# High Service calls vs churn users and non-churn users
# Churn              False  True
# High Service call
# False               2721   345
# True                 129   138
#
#
# High Service calls vs only churn users
# Churn              True
# High Service call
# False               345
# True                138

# %%
#Ploting donought chart for only high service users against churn
plt.figure(figsize=(10,6))
plt.pie(cross_table_high_service_calls_vs_churn.iloc[:,1:], explode = (0,0.3),autopct='%1.2f%%',shadow=True,radius = 2.0, labels = ['Not churned customer','Churned customer'])
circle = plt.Circle( (0,0), 1, color='white')
p=plt.gcf()
p.gca().add_artist(circle)
plt.show()
# Out:
# <ipython-input-59-9567e9fb7f0a>:3: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   plt.pie(cross_table_high_service_calls_vs_churn.iloc[:,1:], explode = (0,0.3),autopct='%1.2f%%',shadow=True,radius = 2.0, labels = ['Not churned customer','Churned customer'])

# %% [markdown]
# Users who are making more than 3 customer service calls, also has very high churn rate of 28.57% (Refer 7.10). User generally do customer service calls for complaints related to network and service issues. And we think churn rate is so high, because unresolved complaints of users.

# %% [markdown]
# # 7.11 Co-relation heatmap

# %%
#ploting heat map of whole data to look for hidden co-relation
plt.figure(figsize=(15, 15))
sns.heatmap(telecom_churn_df.corr(), cmap="Blues",fmt=".2f", annot=True)

# %% [markdown]
# # 8. Conclusion

# %% [markdown]
# 1. Foremost, by analysing overall data, it is found that total 14.5% users are leaving.
# 2. Out of 51 states, following are the list of 18 states which has highest churned rate. For other state, Churn rate was dropped drastically.
# States_list:-NJ
# CA
# TX
# MD
# SC
# MI
# MS
# NV
# WA
# ME
# MT
# AR
# KS
# NY
# MN
# PA
# MA
# CT
# 3. There are total 323 International Plan users and out of them 186 users are churn. So, overall churn rate for international plan user becomes 42.4%. By observations, there are 3 possible reason for this.
# ##### a) Either the international plan has high charges.
# ##### b) There are network related issues.
# #####c) Maybe there is another service provider which offers cheap plans.
# 4. Total Voice Plan users are 922 and out of total Voice Plan Users 80 users are churn. So the churn rate for voice plan users becomes 8.68%. From oberservation, we can say that voice plan users have no effect on churned rate.So voice plan user are satisfied with company services.
# 5. We have seen total talk time and Total charges(refer 7.7 and 7.8 ) is increasing,with churn rate. And in total talk time vs Total charges plot(Refer 7.9) it is found that for high talk time, high charges were charged. And we think because of high talk time service charges users are leaving our services.
# 6. Users who are making more than 3 customer service calls, also has very high churn rate of 28.57% (Refer 7.10). User generally do customer service calls for complaints related to network and service issues. And we think churn rate is so high, because unresolved complaints of users.
